# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
totalelig2021 = pd.read_csv('/Users/danielle.arneson/Desktop/aggregated_population_insights_eligibility_2021.csv')
# Out:
# /Users/danielle.arneson/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (43) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
totalelig2021.head()
# Out:
#    eligibility_sk  program_sk  client_sk                               aid  \
# 0        30527065         872        284  dcbd4e7a785a4cd2ac7929a70234667b
# 1        33801236         950        366  eaec1cbcaa6f429e8076ac884bd06210
# 2        25469328        1460        453  15b07a36dba5443c9cc5be343bff3c37
# 3        27483144        1173        287  af3f10d2a4ff4a9f9e2d5690b3233e49
# 4        26376577         779        158  ea8eca3fdd874ea785d66e42e23f4fe9
#
#                        participant_code  gender  birth_date  \
# 0  dcbd4e7a-785a-4cd2-ac79-29a70234667b  Female  1977-09-09
# 1  eaec1cbc-aa6f-429e-8076-ac884bd06210  Female  1982-05-24
# 2  15b07a36-dba5-443c-9cc5-be343bff3c37  Female  1993-02-03
# 3  af3f10d2-a4ff-4a9f-9e2d-5690b3233e49  Female  1981-01-12
# 4  ea8eca3f-dd87-4ea7-85d6-6e42e23f4fe9    Male  1981-08-28
#
#            program_name  program_year program_status  ... is_test_participant  \
# ...

# %%
program = totalelig2021.groupby(['program_name']).count()

# %%
program.head(50)
# Out:
#                                   eligibility_sk  program_sk  client_sk  \
# program_name
# ABB 2017                                   28398       28398      28398
# ABB 2018                                   28028       28028      28028
# ABB 2019                                   27658       27658      27658
# ABB 2020                                   17827       17827      17827
# ABB 2021                                   17616       17616      17616
# ABB DEMO                                       4           4          4
# ABBES 2020                                  5356        5356       5356
# ABD 2014                                     137         137        137
# ABD 2015                                     168         168        168
# ABD 2016                                     216         216        216
# ABD 2017                                     247         247        247
# ABD 2018                                     284         284        284
# ...

# %%
program = program.reset_index()

# %%
program.head()
# Out:
#   program_name  eligibility_sk  program_sk  client_sk    aid  \
# 0     ABB 2017           28398       28398      28398  28398
# 1     ABB 2018           28028       28028      28028  28028
# 2     ABB 2019           27658       27658      27658  27658
# 3     ABB 2020           17827       17827      17827  17827
# 4     ABB 2021           17616       17616      17616  17616
#
#    participant_code  gender  birth_date  program_year  program_status  ...  \
# 0             28398   28398       28398         28398           28398  ...
# 1             28028   28028       28028         28028           28028  ...
# 2             27658   27658       27658         27658           27658  ...
# 3             17827   17827       17827         17827           17827  ...
# 4             17616   17616       17616         17616           17616  ...
#
#    is_test_participant  health_plan  location  region  country  district  \
# ...

# %%
newProgram = program[(program['program_name'].str.contains('2021'))]

# %%
newProgram.head(50)
# Out:
#                                  program_name  eligibility_sk  program_sk  \
# 4                                    ABB 2021           17616       17616
# 18                        ACUMENT GLOBAL 2021            1056        1056
# 56                                 AMCOR 2021           14086       14086
# 70                                   APS 2021            5808        5808
# 88                                ASCENT 2021             398         398
# 99                            ASICS 2020-2021             739         739
# 100                           ASICS 2020/2021             750         750
# 105                             ASSURANT 2021           17044       17044
# 113                           ATC 2020 - 2021             946         946
# 125             BAYVIEW ASSET MANAGEMENT 2021            1826        1826
# 167                             BIOMARIN 2021            2149        2149
# 182                    BOARD OF PENSIONS 2021           19962       19962
# ...

# %%
update_program = newProgram[(~newProgram['program_name'].str.contains('AMCOR'))]

# %%
update_program.head(70)
# Out:
#                  program_name  eligibility_sk  program_sk  client_sk    aid  \
# 4                    ABB 2021           17616       17616      17616  17616
# 18        ACUMENT GLOBAL 2021            1056        1056       1056   1056
# 70                   APS 2021            5808        5808       5808   5808
# 88                ASCENT 2021             398         398        398    398
# 99            ASICS 2020-2021             739         739        739    739
# ..                        ...             ...         ...        ...    ...
# 612               FISERV 2021           35501       35501      35501  35501
# 652  HAZELDEN BETTY FORD 2021            1717        1717       1717   1717
# 718         HYLANT GROUP 2021            1293        1293       1293   1293
# 746          IOWA CLINIC 2021             980         980        980    980
# 755        IRON MOUNTAIN 2021           10603       10603      10603  10603
#
# ...

# %%
update_program2 = update_program[(~update_program['program_name'].str.contains('HAZELDEN BETTY FORD'))]

# %%
s

# %%
update_program3.head(70)
# Out:
#             program_name  eligibility_sk  program_sk  client_sk    aid  \
# 4               ABB 2021           17616       17616      17616  17616
# 18   ACUMENT GLOBAL 2021            1056        1056       1056   1056
# 70              APS 2021            5808        5808       5808   5808
# 88           ASCENT 2021             398         398        398    398
# 99       ASICS 2020-2021             739         739        739    739
# ..                   ...             ...         ...        ...    ...
# 612          FISERV 2021           35501       35501      35501  35501
# 718    HYLANT GROUP 2021            1293        1293       1293   1293
# 746     IOWA CLINIC 2021             980         980        980    980
# 755   IRON MOUNTAIN 2021           10603       10603      10603  10603
# 781          KIMRAY 2021             609         609        609    609
#
#      participant_code  gender  birth_date  program_year  program_status  ...  \
# ...

# %%
update_program4 = update_program3[(~update_program3['program_name'].str.contains('LITTELFUSE'))]

# %%
update_program5 = update_program4[(~update_program4['program_name'].str.contains('MACQUARIE'))]

# %%
update_program6 = update_program5[(~update_program5['program_name'].str.contains('FISERV'))]

# %%
update_program6.head(75)
# Out:
#                     program_name  eligibility_sk  program_sk  client_sk  \
# 4                       ABB 2021           17616       17616      17616
# 18           ACUMENT GLOBAL 2021            1056        1056       1056
# 70                      APS 2021            5808        5808       5808
# 88                   ASCENT 2021             398         398        398
# 99               ASICS 2020-2021             739         739        739
# ..                           ...             ...         ...        ...
# 800      KINDRED HEALTHCARE 2021           28357       28357      28357
# 838  LEHIGH UNIVERSITY 2020/2021            2657        2657       2657
# 852      LEVI STRAUSS & CO. 2021            4647        4647       4647
# 864             LG&E AND KU 2021            5912        5912       5912
# 890            MALLINCKRODT 2021            5842        5842       5842
#
#        aid  participant_code  gender  birth_date  program_year  \
# ...

# %%
updated_program2021= update_program6['eligibility_sk'].sum()

# %%
print(updated_program2021)
# Out:
# 990197

# %%
newProgram2020 = program[(program['program_name'].str.contains('2020'))]

# %%
newProgram2020.head()
# Out:
#            program_name  eligibility_sk  program_sk  client_sk    aid  \
# 3              ABB 2020           17827       17827      17827  17827
# 6            ABBES 2020            5356        5356       5356   5356
# 17  ACUMENT GLOBAL 2020            1088        1088       1088   1088
# 34        AFFINION 2020            1110        1110       1110   1110
# 39       AKIN GUMP 2020            2292        2292       2292   2292
#
#     participant_code  gender  birth_date  program_year  program_status  ...  \
# 3              17827   17827       17827         17827           17827  ...
# 6               5356    5356        5356          5356            5356  ...
# 17              1088    1088        1088          1088            1088  ...
# 34              1110    1110        1110          1110            1110  ...
# 39              2292    2292        2292          2292            2292  ...
#
#     is_test_participant  health_plan  location  region  country  district  \
# ...

# %%
update_program2020 = newProgram2020[(~newProgram2020['program_name'].str.contains('AMCOR'))]

# %%
update_program2020 = update_program2020[(~update_program2020['program_name'].str.contains('LITTELFUSE'))]

# %%
update_program2020 = update_program2020[(~update_program2020['program_name'].str.contains('MACQUARIE'))]

# %%
update_program2020 = update_program2020[(~update_program2020['program_name'].str.contains('FISERV'))]

# %%
update_program2020 = update_program2020[(~update_program2020['program_name'].str.contains('SNAP'))]

# %%
update_program2020 = update_program2020[(~update_program2020['program_name'].str.contains('FEDERAL'))]

# %%
update_program2020 = update_program2020[(~update_program2020['program_name'].str.contains('MERCY-TEMP'))]

# %%
update_program2020 = update_program2020[(~update_program2020['program_name'].str.contains('EA'))]

# %%
updated_program2020= update_program2020['eligibility_sk'].sum()

# %%
print(updated_program2020)
# Out:
# 1662410

# %%
updated_program2020.head(50)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-1bcb850d16a8> in <module>
# ----> 1 updated_program2020.head(50)
#
# AttributeError: 'numpy.int64' object has no attribute 'head'
